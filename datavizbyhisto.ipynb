# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# bạn hãy tải file dữ liệu trên dự án của tôi về để dẫn đến thư mục trên máy tính của bạn cho đúng
df = pd.read_csv('E:/ML/heights.csv')

# Display head of dataset
print(df.head())
# Out:
#     sex  height
# 0  Male    75.0
# 1  Male    70.0
# 2  Male    68.0
# 3  Male    74.0
# 4  Male    61.0

# %%
sns.histplot(data = df, x="height")

plt.show()

# %%
sns.histplot(data=df, x="height", hue="sex")

plt.show()

# %%
sns.histplot(data = df[df.sex=='Male']['height'], color='blue')

plt.show()

# %%
sns.histplot(data = df[df.sex=='Female']['height'], color='orange')

plt.show()

# %%
sns.histplot(data=df, x='height', kde=True)
plt.show()

# %%
sns.histplot(data=df, x="height", hue="sex", kde = 'True')

plt.show()
